# %%
from flask import Flask, request, jsonify, render_template
import pickle
import numpy as np

app = Flask(__name__)

# Load the trained model
with open('linear_regression_model.pkl', 'rb') as file:
    model = pickle.load(file)

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/predict', methods=['POST'])
def predict():
    data = request.form
    population = float(data['population'])
    rain = float(data['rain'])

    # Create a feature array for prediction
    features = np.array([[population, rain]])
    
    # Make prediction using the loaded model
    prediction = model.predict(features)

    # Return prediction result
    result = 'Drought' if prediction[0] else 'No Drought'
    return render_template('index.html', prediction_text=f'The model predicts: {result}')

@app.route('/api/predict', methods=['POST'])
def api_predict():
    data = request.get_json()
    population = data['population']
    rain = data['rain']

    # Create a feature array for prediction
    features = np.array([[population, rain]])

    # Make prediction using the loaded model
    prediction = model.predict(features)
    
    # Return prediction result as JSON
    result = {'prediction': 'Drought' if prediction[0] else 'No Drought'}
    return jsonify(result)

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Aug/2024 21:03:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:03:44] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [30/Aug/2024 21:03:44] "GET /favicon.ico HTTP/1.1" 404 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:03:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:03:52] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:04] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:11] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:11] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:17] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:22] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:22] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:28] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:28] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:33] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:33] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:40] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:40] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:47] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:52] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:04:57] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:04:57] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:05:02] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:05:02] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:05:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:05:07] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:05:11] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:05:11] "GET /static/style.css HTTP/1.1" 304 -
# C:\Users\Aniket Kumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [30/Aug/2024 21:05:20] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Aug/2024 21:05:20] "GET /static/style.css HTTP/1.1" 304 -

# %%
curl -X POST http://127.0.0.1:5000/api/predict -H "Content-Type: application/json" -d '{"population": 10000, "rain": 250}'
